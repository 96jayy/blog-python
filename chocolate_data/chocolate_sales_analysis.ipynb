# %% [markdown]
# 기본 패키지 불러오기

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 데이터 불러오기

# %%
data=pd.read_csv("C:/Users/rharoal12/Desktop/Study/blog-python/Chocolate Sales.csv")

# %% [markdown]
# 데이터 확인

# %%
data
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 51.4+ KB

# %% [markdown]
# ydata_profiling 패키지 및 ProfileReport 함수 불러오기
# !pip install ydata-profiling : 패키지 설치 코드

# %%
import ydata_profiling
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
ProfileReport(data)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 6/6 [00:00<00:00, 58.39it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-04-04 11:42:11.549558&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# 범주의 갯수가 많은 데이터 재확인

# %%
data['Sales Person'].value_counts()
# Out:
# Sales Person
# Kelci Walkden          54
# Brien Boise            53
# Van Tuxwell            51
# Beverie Moffet         50
# Dennison Crosswaite    49
# Oby Sorrel             49
# Ches Bonnell           48
# Karlen McCaffrey       47
# Gigi Bohling           47
# Curtice Advani         46
# Kaine Padly            45
# Madelene Upcott        45
# Marney O'Breen         45
# Barr Faughny           43
# Jehu Rudeforth         43
# Roddy Speechley        43
# Gunar Cockshoot        43
# Mallorie Waber         41
# Jan Morforth           39
# Andria Kimpton         39
# Husein Augar           38
# Dotty Strutley         36
# Wilone O'Kielt         34
# Rafaelita Blaksland    34
# Camilla Castle         32
# Name: count, dtype: int64

# %%
data['Product'].value_counts()
# Out:
# Product
# 50% Dark Bites          60
# Eclairs                 60
# Smooth Sliky Salty      59
# White Choc              58
# Drinking Coco           56
# Spicy Special Slims     54
# Organic Choco Syrup     52
# After Nines             50
# 85% Dark Bars           50
# Fruit & Nut Bars        50
# Milk Bars               49
# Peanut Butter Cubes     49
# 99% Dark & Pure         49
# Almond Choco            48
# Raspberry Choco         48
# Orange Choco            47
# Mint Chip Choco         45
# Manuka Honey Choco      45
# Caramel Stuffed Bars    43
# 70% Dark Bites          42
# Baker's Choco Chips     41
# Choco Coated Almonds    39
# Name: count, dtype: int64

# %% [markdown]
# Amount 데이터 수정

# %%
data['Amount']
# Out:
# 0        $5,320
# 1        $7,896
# 2        $4,501
# 3       $12,726
# 4       $13,685
#           ...
# 1089     $4,410
# 1090     $6,559
# 1091       $574
# 1092     $2,086
# 1093     $5,075
# Name: Amount, Length: 1094, dtype: object

# %%
data['Amount'].str.replace('$','').str.replace(',','')
# Out:
# 0        5320
# 1        7896
# 2        4501
# 3       12726
# 4       13685
#          ...
# 1089     4410
# 1090     6559
# 1091      574
# 1092     2086
# 1093     5075
# Name: Amount, Length: 1094, dtype: object

# %%
data['Amount']=pd.to_numeric(data['Amount'].str.replace('$','').str.replace(',',''))

# %%
data['Amount']
# Out:
# 0        5320
# 1        7896
# 2        4501
# 3       12726
# 4       13685
#         ...
# 1089     4410
# 1090     6559
# 1091      574
# 1092     2086
# 1093     5075
# Name: Amount, Length: 1094, dtype: int64

# %%
ProfileReport(data)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 6/6 [00:00<00:00, 70.87it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-04-04 11:42:14.026997&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# 날짜 데이터 변환

# %%
data['Date']=pd.to_datetime(data['Date'])
# Out:
# C:\Users\rharoal12\AppData\Local\Temp\ipykernel_17488\1428478067.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date']=pd.to_datetime(data['Date'])

# %%
data
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1          Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   int64
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 51.4+ KB

# %% [markdown]
# 인덱싱으로 train test 분할하기

# %%
train_index=data.loc[:round(len(data)*0.8),:]
test_index=data.loc[round(len(data)*0.8)+1:,:]

# %%
train_index
# Out:
#             Sales Person      Country              Product       Date  Amount  \
# 0         Jehu Rudeforth           UK      Mint Chip Choco 2022-01-04    5320
# 1            Van Tuxwell        India        85% Dark Bars 2022-08-01    7896
# 2           Gigi Bohling        India  Peanut Butter Cubes 2022-07-07    4501
# 3           Jan Morforth    Australia  Peanut Butter Cubes 2022-04-27   12726
# 4         Jehu Rudeforth           UK  Peanut Butter Cubes 2022-02-24   13685
# ..                   ...          ...                  ...        ...     ...
# 871  Rafaelita Blaksland  New Zealand          After Nines 2022-07-07    1099
# 872      Madelene Upcott  New Zealand      Mint Chip Choco 2022-03-11    7413
# 873      Madelene Upcott           UK       70% Dark Bites 2022-02-16    5397
# 874         Barr Faughny    Australia  Organic Choco Syrup 2022-01-07    2303
# 875       Beverie Moffet  New Zealand        Drinking Coco 2022-01-12    1141
#
#      Boxes Shipped
# 0              180
# 1               94
# 2               91
# 3              342
# 4              184
# ..             ...
# 871             92
# 872              4
# 873            239
# 874             33
# 875            518
#
# [876 rows x 6 columns]

# %%
test_index
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 876     Beverie Moffet      India              Eclairs 2022-06-09   10325
# 877     Andria Kimpton      India              Eclairs 2022-05-16    2149
# 878       Gigi Bohling         UK        85% Dark Bars 2022-06-23   12362
# 879    Roddy Speechley         UK      Raspberry Choco 2022-01-28   12635
# 880     Dotty Strutley         UK      Mint Chip Choco 2022-07-14    2443
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 876             147
# 877              84
# 878              94
# 879             194
# 880             216
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [218 rows x 6 columns]

# %% [markdown]
# inplace=True, drop=True 옵션을 사용하지 않았을 경우

# %%
test_index.reset_index()
test_index
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 876     Beverie Moffet      India              Eclairs 2022-06-09   10325
# 877     Andria Kimpton      India              Eclairs 2022-05-16    2149
# 878       Gigi Bohling         UK        85% Dark Bars 2022-06-23   12362
# 879    Roddy Speechley         UK      Raspberry Choco 2022-01-28   12635
# 880     Dotty Strutley         UK      Mint Chip Choco 2022-07-14    2443
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 876             147
# 877              84
# 878              94
# 879             194
# 880             216
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [218 rows x 6 columns]

# %% [markdown]
# inplace=True, drop=False 옵션을 사용하였을 경우

# %%
test_index.reset_index(inplace=True)
test_index
# Out:
#      index      Sales Person    Country              Product       Date  \
# 0      876    Beverie Moffet      India              Eclairs 2022-06-09
# 1      877    Andria Kimpton      India              Eclairs 2022-05-16
# 2      878      Gigi Bohling         UK        85% Dark Bars 2022-06-23
# 3      879   Roddy Speechley         UK      Raspberry Choco 2022-01-28
# 4      880    Dotty Strutley         UK      Mint Chip Choco 2022-07-14
# ..     ...               ...        ...                  ...        ...
# 213   1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17
# 214   1090    Jehu Rudeforth        USA           White Choc 2022-06-07
# 215   1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26
# 216   1092    Dotty Strutley      India              Eclairs 2022-07-28
# 217   1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23
#
#      Amount  Boxes Shipped
# 0     10325            147
# 1      2149             84
# 2     12362             94
# 3     12635            194
# 4      2443            216
# ..      ...            ...
# 213    4410            323
# 214    6559            119
# 215     574            217
# 216    2086            384
# 217    5075            344
#
# [218 rows x 7 columns]

# %% [markdown]
# test_index 데이터 다시 불러오기

# %%
test_index=data.loc[round(len(data)*0.8)+1:,:]
test_index
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 876     Beverie Moffet      India              Eclairs 2022-06-09   10325
# 877     Andria Kimpton      India              Eclairs 2022-05-16    2149
# 878       Gigi Bohling         UK        85% Dark Bars 2022-06-23   12362
# 879    Roddy Speechley         UK      Raspberry Choco 2022-01-28   12635
# 880     Dotty Strutley         UK      Mint Chip Choco 2022-07-14    2443
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 876             147
# 877              84
# 878              94
# 879             194
# 880             216
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [218 rows x 6 columns]

# %% [markdown]
# inplace=True, drop=True 옵션을 사용한 경우

# %%
test_index.reset_index(inplace=True, drop=True)
test_index
# Out:
#          Sales Person    Country              Product       Date  Amount  \
# 0      Beverie Moffet      India              Eclairs 2022-06-09   10325
# 1      Andria Kimpton      India              Eclairs 2022-05-16    2149
# 2        Gigi Bohling         UK        85% Dark Bars 2022-06-23   12362
# 3     Roddy Speechley         UK      Raspberry Choco 2022-01-28   12635
# 4      Dotty Strutley         UK      Mint Chip Choco 2022-07-14    2443
# ..                ...        ...                  ...        ...     ...
# 213  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 214    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 215      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 216    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 217  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#      Boxes Shipped
# 0              147
# 1               84
# 2               94
# 3              194
# 4              216
# ..             ...
# 213            323
# 214            119
# 215            217
# 216            384
# 217            344
#
# [218 rows x 6 columns]

# %%
data
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1          Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %% [markdown]
# sample 함수를 이용한 분할

# %%
train_sample=data.sample(frac=0.8)
test_sample=data.drop(train_sample.index)

# %%
train_sample
# Out:
#         Sales Person      Country              Product       Date  Amount  \
# 45       Kaine Padly          USA  Peanut Butter Cubes 2022-02-16    6790
# 784    Kelci Walkden        India       70% Dark Bites 2022-06-06    3640
# 158   Jehu Rudeforth       Canada   Smooth Sliky Salty 2022-07-11    5460
# 189     Barr Faughny           UK       50% Dark Bites 2022-01-28     581
# 727   Wilone O'Kielt  New Zealand              Eclairs 2022-03-11    3311
# ...              ...          ...                  ...        ...     ...
# 49    Curtice Advani        India     Fruit & Nut Bars 2022-07-07    5243
# 574      Kaine Padly    Australia            Milk Bars 2022-06-09    4046
# 1000  Camilla Castle       Canada        Drinking Coco 2022-03-03   12481
# 876   Beverie Moffet        India              Eclairs 2022-06-09   10325
# 721   Andria Kimpton           UK      99% Dark & Pure 2022-07-25    1155
#
#       Boxes Shipped
# 45              188
# 784             106
# 158             138
# 189              65
# 727              22
# ...             ...
# 49              176
# 574              89
# 1000            264
# 876             147
# 721              66
#
# [875 rows x 6 columns]

# %%
test_sample
# Out:
#              Sales Person    Country              Product       Date  Amount  \
# 1             Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 3            Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 19         Curtice Advani         UK        85% Dark Bars 2022-06-08    1085
# 21        Gunar Cockshoot        USA  Spicy Special Slims 2022-02-17    1267
# 25       Karlen McCaffrey      India     Fruit & Nut Bars 2022-01-26     168
# ...                   ...        ...                  ...        ...     ...
# 1066      Roddy Speechley     Canada        Drinking Coco 2022-05-17    6776
# 1071  Dennison Crosswaite     Canada        Drinking Coco 2022-01-10    2702
# 1075      Roddy Speechley      India  Spicy Special Slims 2022-03-22   10647
# 1079         Jan Morforth         UK  Baker's Choco Chips 2022-03-11     721
# 1090       Jehu Rudeforth        USA           White Choc 2022-06-07    6559
#
#       Boxes Shipped
# 1                94
# 3               342
# 19              172
# 21              157
# 25              321
# ...             ...
# 1066            312
# 1071             24
# 1075            173
# 1079            251
# 1090            119
#
# [219 rows x 6 columns]

# %%
train_sample.reset_index(inplace=True,drop=True)
test_sample.reset_index(inplace=True,drop=True)

# %%
train_sample
# Out:
#        Sales Person      Country              Product       Date  Amount  \
# 0       Kaine Padly          USA  Peanut Butter Cubes 2022-02-16    6790
# 1     Kelci Walkden        India       70% Dark Bites 2022-06-06    3640
# 2    Jehu Rudeforth       Canada   Smooth Sliky Salty 2022-07-11    5460
# 3      Barr Faughny           UK       50% Dark Bites 2022-01-28     581
# 4    Wilone O'Kielt  New Zealand              Eclairs 2022-03-11    3311
# ..              ...          ...                  ...        ...     ...
# 870  Curtice Advani        India     Fruit & Nut Bars 2022-07-07    5243
# 871     Kaine Padly    Australia            Milk Bars 2022-06-09    4046
# 872  Camilla Castle       Canada        Drinking Coco 2022-03-03   12481
# 873  Beverie Moffet        India              Eclairs 2022-06-09   10325
# 874  Andria Kimpton           UK      99% Dark & Pure 2022-07-25    1155
#
#      Boxes Shipped
# 0              188
# 1              106
# 2              138
# 3               65
# 4               22
# ..             ...
# 870            176
# 871             89
# 872            264
# 873            147
# 874             66
#
# [875 rows x 6 columns]

# %%
test_sample
# Out:
#             Sales Person    Country              Product       Date  Amount  \
# 0            Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 1           Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 2         Curtice Advani         UK        85% Dark Bars 2022-06-08    1085
# 3        Gunar Cockshoot        USA  Spicy Special Slims 2022-02-17    1267
# 4       Karlen McCaffrey      India     Fruit & Nut Bars 2022-01-26     168
# ..                   ...        ...                  ...        ...     ...
# 214      Roddy Speechley     Canada        Drinking Coco 2022-05-17    6776
# 215  Dennison Crosswaite     Canada        Drinking Coco 2022-01-10    2702
# 216      Roddy Speechley      India  Spicy Special Slims 2022-03-22   10647
# 217         Jan Morforth         UK  Baker's Choco Chips 2022-03-11     721
# 218       Jehu Rudeforth        USA           White Choc 2022-06-07    6559
#
#      Boxes Shipped
# 0               94
# 1              342
# 2              172
# 3              157
# 4              321
# ..             ...
# 214            312
# 215             24
# 216            173
# 217            251
# 218            119
#
# [219 rows x 6 columns]

# %% [markdown]
# train_test_split 함수 불러오기
# !pip install scikit-learn : 패키지 설치 코드

# %%
from sklearn.model_selection import train_test_split

# %%
train_split,test_split=train_test_split(data,train_size=0.8)

# %%
train_split
# Out:
#         Sales Person      Country               Product       Date  Amount  \
# 920   Wilone O'Kielt        India               Eclairs 2022-02-25    3549
# 603   Jehu Rudeforth        India   Baker's Choco Chips 2022-06-06    2086
# 747      Van Tuxwell       Canada        50% Dark Bites 2022-05-12   13685
# 477     Barr Faughny  New Zealand               Eclairs 2022-03-28    6713
# 519    Kelci Walkden  New Zealand         Drinking Coco 2022-03-10   15855
# ..               ...          ...                   ...        ...     ...
# 201   Camilla Castle  New Zealand       Mint Chip Choco 2022-06-13    1162
# 746     Ches Bonnell        India  Caramel Stuffed Bars 2022-06-15    6839
# 497      Kaine Padly          USA   Organic Choco Syrup 2022-03-11    2380
# 661  Gunar Cockshoot       Canada        50% Dark Bites 2022-01-04    3024
# 892      Van Tuxwell    Australia   Baker's Choco Chips 2022-05-11   13258
#
#      Boxes Shipped
# 920             76
# 603             74
# 747             58
# 477             31
# 519            111
# ..             ...
# 201            190
# 746             56
# 497             22
# 661             23
# 892             32
#
# [875 rows x 6 columns]

# %%
test_split
# Out:
#          Sales Person      Country              Product       Date  Amount  \
# 574       Kaine Padly    Australia            Milk Bars 2022-06-09    4046
# 16        Van Tuxwell       Canada  Organic Choco Syrup 2022-02-14    4067
# 1029   Jehu Rudeforth    Australia          After Nines 2022-02-14    5250
# 528       Brien Boise          USA      99% Dark & Pure 2022-07-25    6769
# 657       Kaine Padly        India       70% Dark Bites 2022-01-24   12173
# ...               ...          ...                  ...        ...     ...
# 1015   Mallorie Waber    Australia   Smooth Sliky Salty 2022-02-11    4158
# 376    Camilla Castle    Australia   Manuka Honey Choco 2022-03-17     637
# 206      Ches Bonnell    Australia      Mint Chip Choco 2022-02-21    9660
# 688   Gunar Cockshoot           UK       50% Dark Bites 2022-01-13    2107
# 1042   Beverie Moffet  New Zealand  Spicy Special Slims 2022-06-07      63
#
#       Boxes Shipped
# 574              89
# 16               42
# 1029             47
# 528             353
# 657             301
# ...             ...
# 1015            109
# 376             169
# 206              92
# 688             121
# 1042             60
#
# [219 rows x 6 columns]

# %%
train_split,test_split=train_test_split(data,train_size=0.8,random_state=96)

# %%
train_split
# Out:
#           Sales Person      Country               Product       Date  Amount  \
# 303       Gigi Bohling    Australia            White Choc 2022-05-11    5523
# 893       Husein Augar  New Zealand   Peanut Butter Cubes 2022-02-16    2058
# 618   Karlen McCaffrey        India         85% Dark Bars 2022-03-30     945
# 1027      Barr Faughny           UK             Milk Bars 2022-03-02    3864
# 21     Gunar Cockshoot          USA   Spicy Special Slims 2022-02-17    1267
# ...                ...          ...                   ...        ...     ...
# 66         Van Tuxwell    Australia   Organic Choco Syrup 2022-08-10   19453
# 609       Jan Morforth    Australia       Mint Chip Choco 2022-02-22   17626
# 364        Van Tuxwell          USA  Caramel Stuffed Bars 2022-02-14     987
# 986     Curtice Advani  New Zealand   Peanut Butter Cubes 2022-03-15    1533
# 84     Roddy Speechley       Canada   Organic Choco Syrup 2022-01-10    4032
#
#       Boxes Shipped
# 303              87
# 893             236
# 618              83
# 1027            430
# 21              157
# ...             ...
# 66               14
# 609             103
# 364              21
# 986             434
# 84               82
#
# [875 rows x 6 columns]

# %%
test_split
# Out:
#              Sales Person      Country              Product       Date  \
# 406          Ches Bonnell       Canada  Spicy Special Slims 2022-08-05
# 776   Dennison Crosswaite        India         Orange Choco 2022-03-18
# 140          Gigi Bohling  New Zealand     Fruit & Nut Bars 2022-04-04
# 765       Gunar Cockshoot        India  Baker's Choco Chips 2022-03-18
# 100   Dennison Crosswaite    Australia      Raspberry Choco 2022-03-14
# ...                   ...          ...                  ...        ...
# 1062  Dennison Crosswaite          USA       70% Dark Bites 2022-03-15
# 104           Brien Boise       Canada  Spicy Special Slims 2022-03-04
# 726          Gigi Bohling       Canada           White Choc 2022-07-11
# 790          Barr Faughny       Canada   Manuka Honey Choco 2022-08-25
# 505           Kaine Padly    Australia       70% Dark Bites 2022-02-08
#
#       Amount  Boxes Shipped
# 406     5327            183
# 776      784            129
# 140    10976            121
# 765     2191            524
# 100     5740             31
# ...      ...            ...
# 1062     658             77
# 104     8106            101
# 726     6587              4
# 790     3402            249
# 505     6706            223
#
# [219 rows x 6 columns]

# %%
train_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
train_split
# Out:
#          Sales Person      Country               Product       Date  Amount  \
# 0        Gigi Bohling    Australia            White Choc 2022-05-11    5523
# 1        Husein Augar  New Zealand   Peanut Butter Cubes 2022-02-16    2058
# 2    Karlen McCaffrey        India         85% Dark Bars 2022-03-30     945
# 3        Barr Faughny           UK             Milk Bars 2022-03-02    3864
# 4     Gunar Cockshoot          USA   Spicy Special Slims 2022-02-17    1267
# ..                ...          ...                   ...        ...     ...
# 870       Van Tuxwell    Australia   Organic Choco Syrup 2022-08-10   19453
# 871      Jan Morforth    Australia       Mint Chip Choco 2022-02-22   17626
# 872       Van Tuxwell          USA  Caramel Stuffed Bars 2022-02-14     987
# 873    Curtice Advani  New Zealand   Peanut Butter Cubes 2022-03-15    1533
# 874   Roddy Speechley       Canada   Organic Choco Syrup 2022-01-10    4032
#
#      Boxes Shipped
# 0               87
# 1              236
# 2               83
# 3              430
# 4              157
# ..             ...
# 870             14
# 871            103
# 872             21
# 873            434
# 874             82
#
# [875 rows x 6 columns]

# %%
test_split
# Out:
#             Sales Person      Country              Product       Date  Amount  \
# 0           Ches Bonnell       Canada  Spicy Special Slims 2022-08-05    5327
# 1    Dennison Crosswaite        India         Orange Choco 2022-03-18     784
# 2           Gigi Bohling  New Zealand     Fruit & Nut Bars 2022-04-04   10976
# 3        Gunar Cockshoot        India  Baker's Choco Chips 2022-03-18    2191
# 4    Dennison Crosswaite    Australia      Raspberry Choco 2022-03-14    5740
# ..                   ...          ...                  ...        ...     ...
# 214  Dennison Crosswaite          USA       70% Dark Bites 2022-03-15     658
# 215          Brien Boise       Canada  Spicy Special Slims 2022-03-04    8106
# 216         Gigi Bohling       Canada           White Choc 2022-07-11    6587
# 217         Barr Faughny       Canada   Manuka Honey Choco 2022-08-25    3402
# 218          Kaine Padly    Australia       70% Dark Bites 2022-02-08    6706
#
#      Boxes Shipped
# 0              183
# 1              129
# 2              121
# 3              524
# 4               31
# ..             ...
# 214             77
# 215            101
# 216              4
# 217            249
# 218            223
#
# [219 rows x 6 columns]
